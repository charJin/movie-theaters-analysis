# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta

# %%
# Load All Stocks Data
netflix_stock_data = pd.read_csv('../data/nflx_stock_data_cleaned.csv')
cnk_stock_data = pd.read_csv('../data/cnk_stock_data_cleaned.csv')
imax_stock_data = pd.read_csv('../data/imax_stock_data_cleaned.csv')
amc_stock_data = pd.read_csv('../data/amc_stock_data_cleaned.csv')
# Load Box Office Movies Data
movies_data = pd.read_csv('../data/movies_data_cleaned.csv')
# Load Netflix Revenue and Subscribers Data
netflix_data = pd.read_csv('../data/netflix_revenue_data_cleaned.csv')

# %% [markdown]
# ## **Stock Trends Analysis**

# %% [markdown]
# >#### **Question:**
# >What is the average quarterly adjusted closing price and total trading volume for Netflix, AMC, Cinemark, and IMAX over the past 10 years?

# %%
def calculate_quarterly_averages(stock_data, stock_name):
    stock_data['date'] = pd.to_datetime(stock_data['date'])
    stock_data.set_index('date', inplace=True)
    quarterly_data = stock_data.resample('QE').agg({
        'adjusted_close': 'mean',
        'volume': 'sum'
    })
    quarterly_data['stock'] = stock_name
    return quarterly_data

# %%
netflix_quarterly = calculate_quarterly_averages(netflix_stock_data, 'Netflix')
amc_quarterly = calculate_quarterly_averages(amc_stock_data, 'AMC')
cnk_quarterly = calculate_quarterly_averages(cnk_stock_data, 'Cinemark')
imax_quarterly = calculate_quarterly_averages(imax_stock_data, 'IMAX')

all_quarterly_data = pd.concat([netflix_quarterly, amc_quarterly, cnk_quarterly, imax_quarterly])

# %%
print(all_quarterly_data)
# Out:
#                            adjusted_close      volume    stock
# date
# 2014-03-31 00:00:00+00:00       57.261335  1295042700  Netflix
# 2014-06-30 00:00:00+00:00       54.112290  1525102600  Netflix
# 2014-09-30 00:00:00+00:00       64.852589   972458900  Netflix
# 2014-12-31 00:00:00+00:00       53.690446  1105811000  Netflix
# 2015-03-31 00:00:00+00:00       60.658946   963482800  Netflix
# ...                                   ...         ...      ...
# 2023-09-30 00:00:00+00:00       18.428730    34173100     IMAX
# 2023-12-31 00:00:00+00:00       17.110635    44764500     IMAX
# 2024-03-31 00:00:00+00:00       15.196066    50574800     IMAX
# 2024-06-30 00:00:00+00:00       16.542222    49881700     IMAX
# 2024-09-30 00:00:00+00:00       17.755714    18669900     IMAX
#
# [172 rows x 3 columns]

# %%
plt.figure(figsize=(14,7))

sns.lineplot(data=netflix_quarterly, x='date', y='adjusted_close', label='Netflix')
sns.lineplot(data=amc_quarterly, x='date', y='adjusted_close', label='AMC')
sns.lineplot(data=cnk_quarterly, x='date', y='adjusted_close', label='Cinemark')
sns.lineplot(data=imax_quarterly, x='date', y='adjusted_close', label='IMAX')

plt.title('Quarterly Total Adjusted Closing Price (2014-2024)')
plt.xlabel('Date')
plt.ylabel('Adjusted Closing Price')
plt.legend(title='Companies')
plt.show()

# %% [markdown]
# > #### **Question:**
# > For each stock, what were the highest and lowest adjusted close prices, and when did they occur?

# %%
def find_high_low_prices(stock_data, stock_name):
    stock_data.reset_index(inplace=True)
    highest = stock_data.loc[stock_data['adjusted_close'].idxmax()]
    lowest = stock_data.loc[stock_data['adjusted_close'].idxmin()]
    highest_price = highest['adjusted_close']
    highest_date = highest['date']
    lowest_price = lowest['adjusted_close']
    lowest_date = lowest['date']

    print(f"{stock_name}")
    print("Highest price : ", f"${highest_price:.2f} in {highest_date}")
    print("Lowest price : ", f"${lowest_price:.2f} in {lowest_date}")

# %%
find_high_low_prices(netflix_stock_data, "Netflix")
find_high_low_prices(amc_stock_data, "AMC")
find_high_low_prices(cnk_stock_data, "Cinemark")
find_high_low_prices(imax_stock_data, "IMAX")
# Out:
# Netflix
# Highest price :  $691.69 in 2021-11-17 00:00:00+00:00
# Lowest price :  $44.89 in 2014-04-28 00:00:00+00:00
# AMC
# Highest price :  $625.50 in 2021-06-02 00:00:00+00:00
# Lowest price :  $2.47 in 2024-04-15 00:00:00+00:00
# Cinemark
# Highest price :  $40.60 in 2019-05-03 00:00:00+00:00
# Lowest price :  $6.58 in 2020-03-18 00:00:00+00:00
# IMAX
# Highest price :  $43.22 in 2015-06-19 00:00:00+00:00
# Lowest price :  $7.16 in 2020-03-17 00:00:00+00:00

# %% [markdown]
# >#### **Question:**
# >How did the year-over-year (YoY) stock price changes compare between AMC, Cinemark, IMAX, and Netflix?

# %%
def calculate_yoy_change(stock_data, stock_name):
    stock_data.set_index('date', inplace=True)

    yearly_average = stock_data['adjusted_close'].resample('YE').mean()
    yoy_change = yearly_average.pct_change() * 100
    yoy_data = pd.DataFrame({f"{stock_name} YoY Change (%)": yoy_change})

    return yoy_data

# %%
netflix_yoy = calculate_yoy_change(netflix_stock_data, "Netflix")
amc_yoy = calculate_yoy_change(amc_stock_data, "AMC")
cnk_yoy = calculate_yoy_change(cnk_stock_data, "Cinemark")
imax_yoy = calculate_yoy_change(imax_stock_data, "IMAX")
yoy_combined = pd.concat([netflix_yoy, amc_yoy, cnk_yoy, imax_yoy], axis=1)
yoy_combined
# Out:
#                            Netflix YoY Change (%)  AMC YoY Change (%)  \
# date
# 2014-12-31 00:00:00+00:00                     NaN                 NaN
# 2015-12-31 00:00:00+00:00               59.832132           27.985473
# 2016-12-31 00:00:00+00:00               11.028465            1.660468
# 2017-12-31 00:00:00+00:00               62.083391          -20.254608
# 2018-12-31 00:00:00+00:00               93.071348          -21.625169
# 2019-12-31 00:00:00+00:00                3.001050          -19.230621
# 2020-12-31 00:00:00+00:00               35.866452          -58.921480
# 2021-12-31 00:00:00+00:00               24.929202          503.191910
# 2022-12-31 00:00:00+00:00              -49.009276          -52.078176
# 2023-12-31 00:00:00+00:00               37.102627          -73.668394
# 2024-12-31 00:00:00+00:00               54.620452          -87.479140
#
#                            Cinemark YoY Change (%)  IMAX YoY Change (%)
# date
# ...

# %%
yoy_combined.max()
# Out:
# Netflix YoY Change (%)      93.071348
# AMC YoY Change (%)         503.191910
# Cinemark YoY Change (%)     23.868744
# IMAX YoY Change (%)         42.435658
# dtype: float64

# %%
min_max_yoy_changes = yoy_combined.idxmax().dt.year.to_frame(name='Max Year')
min_max_yoy_changes['Max YoY Change (%)'] = yoy_combined.max()
min_max_yoy_changes['Min Year'] = yoy_combined.idxmin().dt.year
min_max_yoy_changes['Min YoY Change (%)'] = yoy_combined.min()
min_max_yoy_changes
# Out:
#                          Max Year  Max YoY Change (%)  Min Year  \
# Netflix YoY Change (%)       2018           93.071348      2022
# AMC YoY Change (%)           2021          503.191910      2024
# Cinemark YoY Change (%)      2021           23.868744      2020
# IMAX YoY Change (%)          2021           42.435658      2020
#
#                          Min YoY Change (%)
# Netflix YoY Change (%)           -49.009276
# AMC YoY Change (%)               -87.479140
# Cinemark YoY Change (%)          -56.587808
# IMAX YoY Change (%)              -37.337215

# %% [markdown]
# ## **Impact of COVID-19 and Industry Recovery**

# %% [markdown]
# >#### **Question:**
# >How has box office gross changed during and after the COVID-19 pandemic?

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 3951 non-null   int64
#  1   date                 3951 non-null   object
#  2   day                  3951 non-null   object
#  3   day_number           3951 non-null   int64
#  4   top10_gross_dollars  3951 non-null   int64
#  5   %± YD                3951 non-null   object
#  6   %± LW                3951 non-null   object
#  7   Releases             3951 non-null   int64
#  8   top1_release         3951 non-null   object
#  9   gross_dollars        3951 non-null   int64
#  10  event                708 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 339.7+ KB

# %%
movies_data.head(5)
# Out:
#    year        date        day  day_number  top10_gross_dollars   %± YD  \
# 0  2014  2014-01-01  Wednesday           1             48419707    +35%
# 1  2014  2014-01-02   Thursday           2             25361378  -47.6%
# 2  2014  2014-01-03     Friday           3             42939384  +69.3%
# 3  2014  2014-01-04   Saturday           4             49402611  +15.1%
# 4  2014  2014-01-05     Sunday           5             26723321  -45.9%
#
#     %± LW  Releases                          top1_release  gross_dollars  \
# 0  -27.9%        49                                Frozen        8718939
# 1  -56.6%        49                                Frozen        5304617
# 2  -26.8%        45  Paranormal Activity: The Marked Ones        8722144
# 3  -19.7%        45                                Frozen        8037475
# 4  -44.1%        45                                Frozen        4785996
#
#             event
# 0  New Year's Day
# 1             NaN
# 2             NaN
# ...

# %%
movies_data['date'] = pd.to_datetime(movies_data['date'])
pre_covid = movies_data[(movies_data['date'] < '2020-03-01')]
during_covid = movies_data[(movies_data['date'] >= '2020-03-01') & (movies_data['date'] < '2021-07-01')]
post_covid = movies_data[movies_data['date'] >= '2021-07-01']

# %%
pre_covid_gross = pre_covid['gross_dollars'].mean()
during_covid_gross = during_covid['gross_dollars'].mean()
post_covid_gross = post_covid['gross_dollars'].mean()

periods = ['Pre-COVID', 'During COVID', 'Post-COVID']
means = [pre_covid_gross, during_covid_gross, post_covid_gross]

plt.figure(figsize=(5, 4))
plt.bar(periods, means, color=['blue', 'orange', 'green'])
plt.title('Average Box Office Gross Before, During, and After COVID-19')
plt.xlabel('Period')
plt.ylabel('Average Gross ($)')
plt.show()

# %%
quarterly_gross = movies_data.resample('QE', on='date')['gross_dollars'].sum()
quarterly_gross = quarterly_gross.iloc[:-1] # The most recent data doesn't have a full quarter (ends in October)
lowest_point = quarterly_gross.min()
highest_point  = quarterly_gross.max()
lowest_date = quarterly_gross.idxmin()
highest_date = quarterly_gross.idxmax()

print("Lowest quarterly gross: ", lowest_point, " on ", lowest_date)
print("Highest quarterly gross: ", highest_point, " on ", highest_date)
# Out:
# Lowest quarterly gross:  1910919  on  2020-06-30 00:00:00
# Highest quarterly gross:  1639365211  on  2018-06-30 00:00:00

# %%
pre_covid_quarterly_avg = pre_covid.resample('QE', on='date')['gross_dollars'].sum().mean()
post_covid_quarterly_avg = post_covid.resample('QE', on='date')['gross_dollars'].sum().mean()

plt.figure(figsize=(12, 6))
plt.plot(quarterly_gross.index, quarterly_gross.values, marker='o', linestyle='-', color='gray', label='Quarterly Gross')
plt.axhline(pre_covid_quarterly_avg, color='orange', linestyle='--', label=f'Pre-COVID Average (${pre_covid_quarterly_avg:,.0f})')

# Mark the highest and lowest points
plt.scatter([lowest_date], [lowest_point], color='red', label=f'Lowest Point ({lowest_date.date()}, ${lowest_point:,.0f})', zorder=5)
plt.scatter([highest_date], [highest_point], color='blue', label=f'Highest Point ({highest_date.date()}, ${highest_point:,.0f})', zorder=5)

plt.title('Quarterly Box Office Gross with Pre-COVID Average')
plt.xlabel('Date')
plt.ylabel('Gross ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
difference = pre_covid_quarterly_avg - post_covid_quarterly_avg
print(f"Post-COVID quarterly average is ${difference:,.0f} less than the Pre-COVID quarterly average.")
# Out:
# Post-COVID quarterly average is $144,573,845 less than the Pre-COVID quarterly average.

# %% [markdown]
# >#### **Question:**
# >How does box office gross compare with Netflix’s subscriber and revenue growth around the pandemic period?

# %% [markdown]
# > ### Quarterly Comparison

# %%
netflix_data['date'] = pd.to_datetime(netflix_data['date'])
netflix_data.set_index('date', inplace=True)
netflix_quarterly_adjusted_close = netflix_quarterly['adjusted_close']

# %%
pre_pandemic_netflix_stock = netflix_quarterly_adjusted_close[:'2020-01-01']
post_pandemic_netflix_stock =netflix_quarterly_adjusted_close['2020-01-01':]

pre_pandemic_netflix_avg = {
    "stock": pre_pandemic_netflix_stock.mean(),
    "ucan_rev": netflix_data['UCAN_rev'][:'2020-01-01'].mean(),
    "ucan_subs": netflix_data['UCAN_subscribers'][:'2020-01-01'].mean()
}

post_pandemic_netflix_avg = {
    "stock": post_pandemic_netflix_stock.mean(),
    "ucan_rev": netflix_data['UCAN_rev']['2020-01-01':].mean(),
    "ucan_subs": netflix_data['UCAN_subscribers']['2020-01-01':].mean()
}

# %%
date_range = netflix_data.index
revenue_values = netflix_data['UCAN_rev']
subscriber_values = netflix_data['UCAN_subscribers']
quarterly_gross = quarterly_gross.reindex(date_range).interpolate() 

# Normalize each series to scale from 0 to 1
# Adding a relatively small constant for each category so minimum will appear in bar chart
revenue_constant = 1e8
subscriber_constant = 1e6
gross_constant = 1e7
revenue_values_normalized = (revenue_values + revenue_constant - revenue_values.min()) / (revenue_values.max() - revenue_values.min())
subscriber_values_normalized = (subscriber_values + subscriber_constant - subscriber_values.min()) / (subscriber_values.max() - subscriber_values.min())
quarterly_gross_normalized = (quarterly_gross + gross_constant - quarterly_gross.min()) / (quarterly_gross.max() - quarterly_gross.min())

fig, ax = plt.subplots(figsize=(14, 8))

x = np.arange(len(date_range))
width = 0.25

# Highlight COVID-19 period
covid_start = '2020-03-31'  # Q1 2020
covid_end = '2021-06-30'    # Q2 2021
covid_start_idx = np.where(date_range == covid_start)[0][0]
covid_end_idx = np.where(date_range == covid_end)[0][0]
ax.axvspan(covid_start_idx, covid_end_idx, color='gray', alpha=0.2, label='COVID-19 Period')


ax.bar(x - width, revenue_values_normalized, width, label='Netflix UCAN Revenue (Normalized)', color='#008B8B')
ax.bar(x, subscriber_values_normalized, width, label='Netflix UCAN Subscribers (Normalized)', color='#40E0D0')
ax.bar(x + width, quarterly_gross_normalized, width, label='Box Office Gross (Normalized)', color='#FF8C00')

ax.set_xlabel('Quarterly Dates')
ax.set_ylabel('Normalized Value (0 to 1)')
ax.set_title('Quarterly Netflix UCAN Revenue, UCAN Subscribers, and Box Office Gross Trends')
ax.set_xticks(x)
ax.set_xticklabels([date.strftime('%Y-%m') for date in date_range], rotation=45)
ax.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## **Movie Viewership Pattern**

# %% [markdown]
# >#### **Question:**
# > What time of year has the highest box office gross?
# Do holiday seasons impact movie viewing? If so, which specific holidays have the most significant effect on box office gross?

# %% [markdown]
# > - #### Day of the Week

# %%
movies_data['day_of_week'] = movies_data['date'].dt.day_name()
avg_gross_by_day = movies_data.groupby('day_of_week')['gross_dollars'].mean().sort_values(ascending=False)
avg_gross_by_day
# Out:
# day_of_week
# Friday       1.785192e+07
# Saturday     1.751010e+07
# Sunday       1.291300e+07
# Tuesday      5.519508e+06
# Monday       5.262073e+06
# Wednesday    4.340232e+06
# Thursday     3.871907e+06
# Name: gross_dollars, dtype: float64

# %%
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
avg_gross_by_day = avg_gross_by_day.reindex(day_order)

# %%
plt.figure(figsize=(8, 5))
avg_gross_by_day.plot(kind='bar', color='darkgreen')
plt.title("Average Box Office Gross by Day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Average Gross ($)")
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate average gross by season
movies_data['season'] = movies_data['date'].dt.month % 12 // 3 + 1
season_names = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
movies_data['season'] = movies_data['season'].map(season_names)

avg_gross_by_season = movies_data.groupby('season')['gross_dollars'].mean()
avg_gross_by_season
# Out:
# season
# Fall      7.417877e+06
# Spring    1.079873e+07
# Summer    1.119063e+07
# Winter    8.913143e+06
# Name: gross_dollars, dtype: float64

# %% [markdown]
# > - #### Holiday Season

# %%
movies_data.head()
# Out:
#    year       date        day  day_number  top10_gross_dollars   %± YD  \
# 0  2014 2014-01-01  Wednesday           1             48419707    +35%
# 1  2014 2014-01-02   Thursday           2             25361378  -47.6%
# 2  2014 2014-01-03     Friday           3             42939384  +69.3%
# 3  2014 2014-01-04   Saturday           4             49402611  +15.1%
# 4  2014 2014-01-05     Sunday           5             26723321  -45.9%
#
#     %± LW  Releases                          top1_release  gross_dollars  \
# 0  -27.9%        49                                Frozen        8718939
# 1  -56.6%        49                                Frozen        5304617
# 2  -26.8%        45  Paranormal Activity: The Marked Ones        8722144
# 3  -19.7%        45                                Frozen        8037475
# 4  -44.1%        45                                Frozen        4785996
#
#             event day_of_week  season
# 0  New Year's Day   Wednesday  Winter
# ...

# %%
movies_data['event'].unique()
# Out:
# array(["New Year's Day", nan, 'MLK Day', 'Sochi Olympics',
#        "Presidents' Day\nSochi Olympics", 'Easter Sunday', 'Memorial Day',
#        'World Cup (Brazil)', 'Independence Day\nWorld Cup (Brazil)',
#        'Labor Day', "Indig. Peoples' Day", 'Halloween', 'Thanksgiving',
#        'Christmas Day', "New Year's Eve", "Presidents' Day",
#        'Mayweather/Pacquiao Fight', 'Independence Day', 'Rio Olympics',
#        'PyeongChang Olympics', "Presidents' Day\nPyeongChang Olympics",
#        'World Cup (Russia)', 'Independence Day\nWorld Cup (Russia)',
#        'COVID-19 Pandemic', 'COVID-19 Pandemic\nEaster Sunday',
#        'COVID-19 Pandemic\nMemorial Day',
#        'COVID-19 Pandemic\nIndependence Day',
#        'COVID-19 Pandemic\nLabor Day',
#        "COVID-19 Pandemic\nIndig. Peoples' Day",
#        'COVID-19 Pandemic\nHalloween', 'COVID-19 Pandemic\nThanksgiving',
#        'COVID-19 Pandemic\nChristmas Day',
#        "COVID-19 Pandemic\nNew Year's Eve",
# ...

# %%
holidays_to_analyze = [
    "New Year's Day", 'MLK Day', "Presidents' Day", 'Easter Sunday', 
    'Memorial Day', 'Independence Day', 'Labor Day', 'Halloween', 
    'Thanksgiving', 'Christmas Day'
]

# %%
def identify_holiday(event):
    if pd.isna(event):
        return None
    for holiday in holidays_to_analyze:
        if holiday in event:
            return holiday
    return None

# %%
movies_data['holiday'] = movies_data['event'].apply(identify_holiday)
movies_holiday_data = movies_data.dropna(subset=['holiday'])

# %%
# Create a `day_count` column that shows 5 days before and after the selected holiday.
# `day_count` of value 1 indicates 5 days before the holiday. 
# `day_count` of value 11 indicates 5 days after the holiday.
holiday_windows = pd.DataFrame()

for _, row in movies_holiday_data.iterrows():
    holiday_date = row['date']
    holiday_name = row['holiday']
    for offset in range(-5, 6):
        current_date = holiday_date + timedelta(days=offset)
        matching_row = movies_data[movies_data['date'] == current_date]
        
        if not matching_row.empty:
            temp_row = matching_row.copy()
            temp_row['holiday'] = holiday_name
            temp_row['day_count'] = offset + 6
            holiday_windows = pd.concat([holiday_windows, temp_row])

holiday_windows.head(5)
# Out:
#    year       date        day  day_number  top10_gross_dollars   %± YD  \
# 0  2014 2014-01-01  Wednesday           1             48419707    +35%
# 1  2014 2014-01-02   Thursday           2             25361378  -47.6%
# 2  2014 2014-01-03     Friday           3             42939384  +69.3%
# 3  2014 2014-01-04   Saturday           4             49402611  +15.1%
# 4  2014 2014-01-05     Sunday           5             26723321  -45.9%
#
#     %± LW  Releases                          top1_release  gross_dollars  \
# 0  -27.9%        49                                Frozen        8718939
# 1  -56.6%        49                                Frozen        5304617
# 2  -26.8%        45  Paranormal Activity: The Marked Ones        8722144
# 3  -19.7%        45                                Frozen        8037475
# 4  -44.1%        45                                Frozen        4785996
#
#             event day_of_week  season         holiday  day_count
# ...

# %%
holiday_stats = (
    holiday_windows.groupby(['holiday', 'year'])['gross_dollars']
    .agg(holiday_10days_gross='mean')
    .reset_index()
)

yearly_stats = (
    movies_data.groupby('year')['gross_dollars']
    .agg(yearly_avg_gross='mean')
    .reset_index()
)

holiday_comparison_stats = holiday_stats.merge(yearly_stats, on='year')

holiday_comparison_stats['pct_diff_from_avg'] = (
    (holiday_comparison_stats['holiday_10days_gross'] - holiday_comparison_stats['yearly_avg_gross']) / holiday_comparison_stats['yearly_avg_gross']
)

holiday_comparison_stats
# Out:
#            holiday  year  holiday_10days_gross  yearly_avg_gross  \
# 0    Christmas Day  2014          1.226195e+07      8.828161e+06
# 1    Christmas Day  2015          4.014737e+07      1.160158e+07
# 2    Christmas Day  2016          2.008411e+07      1.148286e+07
# 3    Christmas Day  2017          2.198469e+07      1.121021e+07
# 4    Christmas Day  2018          1.712721e+07      1.173417e+07
# ..             ...   ...                   ...               ...
# 103   Thanksgiving  2019          2.319678e+07      1.289533e+07
# 104   Thanksgiving  2020          1.487844e+06      1.886578e+06
# 105   Thanksgiving  2021          7.190461e+06      6.006740e+06
# 106   Thanksgiving  2022          1.215176e+07      1.009578e+07
# 107   Thanksgiving  2023          7.725890e+06      1.022462e+07
#
#      pct_diff_from_avg
# 0             0.388959
# 1             2.460508
# 2             0.749052
# 3             0.961131
# 4             0.459601
# ..                 ...
# ...

# %%
holiday_summary = (
    holiday_comparison_stats.groupby('holiday')
    .agg(avg_pct_diff=('pct_diff_from_avg', 'mean'))
    .reset_index()
)

holiday_summary.sort_values(by='avg_pct_diff', ascending=False)
# Out:
#             holiday  avg_pct_diff
# 0     Christmas Day      1.128332
# 8   Presidents' Day      0.445304
# 7    New Year's Day      0.429288
# 3  Independence Day      0.407607
# 6      Memorial Day      0.279191
# 9      Thanksgiving      0.228635
# 1     Easter Sunday      0.166172
# 5           MLK Day      0.058756
# 4         Labor Day     -0.231176
# 2         Halloween     -0.376929

# %%
top_holidays = ['Christmas Day', "Presidents' Day", "New Year's Day", 'Independence Day']
top_holiday_data = holiday_windows[holiday_windows['holiday'].isin(selected_holidays)]

# Plot gross distribution by day of the week for the top 4 holidays.
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_holiday_data,
    x='day',
    y='gross_dollars',
    hue='holiday',
    palette='Set3',
    order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)
plt.title("Average Gross Dollars by Day of the Week for Top 4 Holidays")
plt.xlabel("Day of the Week")
plt.ylabel("Gross Dollars")
plt.legend(title='Holiday')
plt.show()

# %% [markdown]
# >#### **Question:**
# >What is the distribution of genres and age restrictions for the top movie release on each day?

# %% [markdown]
# >#### **Question:**
# >What percentage of movies released in theaters are available on Netflix?
# >Which types of theatrical releases are most likely to transition to Netflix? (e.g., Does Netflix pick up more family films, or are they more likely to add dramas and thrillers after their box office run?)
